# %%
import sklearn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score,confusion_matrix 

class eksperimen(object):
    def __init__(self, dataset=None, classifier=None, X=None, y=None, dataset_split=None):
        self.dataset = dataset
        self.classifier = classifier
        self.X = X
        self.y = y
        self.dataset_split = dataset_split

    def get_std_dataset(self):
        self.dataset = load_iris()
        self.X = self.dataset['data']
        self.y = self.dataset['target']
        print(self.X)

    def printmatrix_accuracy_percentage(self):
        predict = self.classifier.predict(X_test)
    
        # accuracy
        print(accuracy_score(dataset['y_test'],predict))

        # metrics confusion
        print(confusion_matrix(dataset['y_test'],predict))
    
    def build_clf_percentage(self, clf_name):
        if (clf_name == 'dtl'):
            self.classifier = DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)
        elif (clf_name == 'ann'):
            self.classifier = MLPClassifier(solver='lbfgs', alpha=1e-5, 
                                            hidden_layer_sizes=(5, 2), random_state=1)
        # training dengan 90% data   
        self.classifier.fit(self.dataset_split['X_train'],self.dataset_split['y_train'])

    def build_clf_full(self,clf_name):
        if (clf_name == 'dtl'):
            self.classifier = DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)
        elif (clf_name == 'ann'):
            self.classifier = MLPClassifier(solver='lbfgs', alpha=1e-5, 
                                            hidden_layer_sizes=(5, 2), random_state=1)
            # training dengan full data   
        self.classifier.fit(self.X,self.y)
    
    def split_dataset(self):
        # X adalah data setiap fitur, y adalah target 
        # split menjadi 90% training 10% testing
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size = 0.1 ,train_size = 0.9)
        self.dataset_split = {
            'X_train': X_train,
            'X_test': X_test,
            'y_train': y_train,
            'y_test': y_test
        }

    def get_dataset(self, filename, class_index):
        # readfile, masukin ke dataset
        raw_data = pd.read_csv(filename)
        
        y = [] # target
        for target in raw_data[raw_data.columns[class_index]]: # play is the name of the class index
            y.append(target)
        self.y = y
        
        X = [] # domain
        i = 0
        jumlah_data = len(raw_data)
        while (i<jumlah_data):
            elem_x = []
            for elem in raw_data.columns:
                elem_x.append(raw_data.loc[i, elem])
            X.append(elem_x)
            i += 1
        self.X = X


#         self.X = self.dataset[:, 1:]  # select columns 1 through end
#         self.y = self.dataset[:, 0]
#     print(X)
#     print(y)
    
    
exp = eksperimen()
exp.get_dataset('tennis.csv', 5)
# exp.get_std_dataset()
# print(exp.y)


# iris = exp.dataset

# X = iris.data
# y = iris.target
# exp.split_dataset()

# exp.build_clf('ann')
# print(exp.classifier)

exp.build_clf_full('dtl')
print(exp.classifier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-caa64dc994ec> in <module>()
#     100 # print(exp.classifier)
#     101
# --> 102 exp.build_clf_full('dtl')
#     103 print(exp.classifier)
#     104
#
# <ipython-input-9-caa64dc994ec> in build_clf_full(self, clf_name)
#      46                                             hidden_layer_sizes=(5, 2), random_state=1)
#      47             # training dengan full data
# ---> 48         self.classifier.fit(self.X,self.y)
#      49
#      50     def split_dataset(self):
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# ~\AppData\Local\Programs\Python\Python36-32\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
